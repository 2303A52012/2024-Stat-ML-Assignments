# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52012/2024-Stat-ML-Assignments/blob/main/2303A52012(Sml)Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Question 1**
# 1. **Read the data with pandas and find features and target variables**
# 2. **Normalize the data with min-max scaling**
# 3. **Split the data into train and test.**

# %% [markdown]
# ## **Reading data**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
train = pd.read_csv('train.csv')

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ## **1.features and target variables and of train**
# ****

# %% [markdown]
# ### **1.a.target variable**

# %%
y=train['price_range']
print(f"the target variable is {y.name} \nand the data is \n")
print(y)
print(f"the range of target variable is {y.min()} - {y.max()}")
# Out:
# the target variable is price_range
# and the data is
#
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64
# the range of target variable is 0 - 3

# %% [markdown]
# ### **1.b.features**

# %%
x=train.drop('price_range',axis=1)
print(f"the features are")
for i in x.columns:
  print(i , end=" , ")
print(f"\nand the data is \n")
print(x)
# Out:
# the features are
# battery_power , blue , clock_speed , dual_sim , fc , four_g , int_memory , m_dep , mobile_wt , n_cores , pc , px_height , px_width , ram , sc_h , sc_w , talk_time , three_g , touch_screen , wifi ,
# and the data is
#
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# ...

# %% [markdown]
# ## **2.Normalize the data with min-max scaling**

# %%
normilize_x=(x-x.min())/(x.max()-x.min())
normilize_x
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %% [markdown]
# ## **3.test and train**

# %%
x_train,x_test,y_train,y_test=train_test_split(normilize_x,y,test_size=0.2,random_state=30)
#test_size is for taking the persentage to be taken for test(a%)(range from 0-1)
#train_size is for taking the persentage to be taken for train(100-a%)(range from 0-1)
#random_state is for shuffling the data in 30 they split for a% for test and 100-a% for train
print(f"the x_train is \n{x_train}")
print(f"the x_test is \n{x_test}")
print(f"the shape of x_train is \n{x_train.shape}")
print(f"the shape of x_test is \n{x_test.shape}")
# Out:
# the x_train is
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1572       0.263193   0.0         0.00       1.0  0.315789     0.0
# 1442       0.315297   0.0         0.00       1.0  0.263158     0.0
# 1516       0.387442   1.0         0.56       1.0  0.684211     1.0
# 259        0.706747   1.0         0.44       1.0  0.315789     1.0
# 945        0.221109   0.0         0.24       0.0  0.000000     1.0
# ...             ...   ...          ...       ...       ...     ...
# 500        0.519038   1.0         0.00       1.0  0.052632     0.0
# 1837       0.321977   0.0         0.04       1.0  0.000000     1.0
# 941        0.161657   0.0         0.00       1.0  0.000000     1.0
# 421        0.452238   0.0         0.68       1.0  0.315789     0.0
# 1829       0.376754   0.0         0.48       1.0  0.210526     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# ...

# %% [markdown]
# # **Question 2**
#
# 1.  **Read the data with pandas and describe the data**
# 2.  F**ind data type and shape of each column**
# 3.  **Find the target and features**
# 4.  **Find the null values (if yes fill the null values with ‘0’ or mean of that column)**
# 5.  **Normalize all the features**
# 6.  **Split the data into train and test.**

# %% [markdown]
# ## **1.Read the data with pandas and describe the data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
data = pd.read_csv('/content/sample_data/california_housing_train.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
print(data.describe())
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ## **2.Find data type and shape of each column**

# %%
for i in data.columns:
  print(f"the data type of {i} is {data[i].dtype}")
  print(f"the shape of {i} is {data[i].shape}\n")
# Out:
# the data type of longitude is float64
# the shape of longitude is (17000,)
#
# the data type of latitude is float64
# the shape of latitude is (17000,)
#
# the data type of housing_median_age is float64
# the shape of housing_median_age is (17000,)
#
# the data type of total_rooms is float64
# the shape of total_rooms is (17000,)
#
# the data type of total_bedrooms is float64
# the shape of total_bedrooms is (17000,)
#
# the data type of population is float64
# the shape of population is (17000,)
#
# the data type of households is float64
# the shape of households is (17000,)
#
# the data type of median_income is float64
# the shape of median_income is (17000,)
#
# the data type of median_house_value is float64
# the shape of median_house_value is (17000,)

# %% [markdown]
# ## **3. Find the target and features**

# %% [markdown]
# ### **target variable**

# %%
y=data['median_house_value']
print(f"the target variable is {y.name} \nand the data is \n")
print(y)
# Out:
# the target variable is median_house_value
# and the data is
#
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %% [markdown]
# ### **features**

# %%
x=data.drop('median_house_value',axis=1)
print(f"the features are")
for i in x.columns:
  print(i , end=" , ")
print(f"\nand the data is \n")
print(x)
# Out:
# the features are
# longitude , latitude , housing_median_age , total_rooms , total_bedrooms , population , households , median_income ,
# and the data is
#
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# ...

# %% [markdown]
# ## **4.Find the null values (if yes fill the null values with ‘0’ or mean of that column)**

# %%
print(f"finding the null values \n{data.isnull()}\n\n")
print(f"the null values in data for each column are \n{data.isnull().sum()}")
# Out:
# finding the null values
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %% [markdown]
# ## **5. Normalize all the features**

# %%
normilize_x=(x-x.min())/(x.max()-x.min())
normilize_x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       1.000000  0.175345            0.274510     0.147885        0.198945
# 1       0.984064  0.197662            0.352941     0.201608        0.294848
# 2       0.975100  0.122210            0.313725     0.018927        0.026847
# 3       0.974104  0.116897            0.254902     0.039515        0.052142
# 4       0.974104  0.109458            0.372549     0.038276        0.050435
# ...          ...       ...                 ...          ...             ...
# 16995   0.008964  0.854410            1.000000     0.058389        0.060987
# 16996   0.007968  0.866100            0.686275     0.061869        0.081782
# 16997   0.004980  0.988310            0.313725     0.070515        0.082247
# 16998   0.004980  0.984060            0.352941     0.070384        0.085506
# 16999   0.000000  0.850159            1.000000     0.047924        0.046400
#
#        population  households  median_income
# ...

# %% [markdown]
# ## **6.Split the data into train and test.**

# %%
x_train,x_test,y_train,y_test=train_test_split(normilize_x,y,test_size=0.2,random_state=50)
#test_size is for taking the persentage to be taken for test(a%)(range from 0-1)
#train_size is for taking the persentage to be taken for train(100-a%)(range from 0-1)
#random_state is for shuffling the data in 30 they split for a% for test and 100-a% for train
print(f"the x_train is \n{x_train}")
print(f"the x_test is \n{x_test}")
print(f"the shape of x_train is \n{x_train.shape}")
print(f"the shape of x_test is \n{x_test.shape}")
# Out:
# the x_train is
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8730    0.574701  0.171095            0.392157     0.101595        0.084730
# 3796    0.638446  0.146652            0.607843     0.027705        0.031968
# 7169    0.599602  0.176408            0.823529     0.034875        0.039261
# 8882    0.554781  0.160468            0.529412     0.035350        0.033209
# 736     0.727092  0.004251            0.411765     0.055331        0.061763
# ...          ...       ...                 ...          ...             ...
# 14565   0.218127  0.565356            0.686275     0.088493        0.076350
# 15649   0.197211  0.834219            0.215686     0.099670        0.108783
# 10123   0.451195  0.448459            0.882353     0.057783        0.087213
# 5600    0.614542  0.176408            0.843137     0.038777        0.038641
# 14000   0.230080  0.510096            0.470588     0.052511        0.044382
#
# ...
